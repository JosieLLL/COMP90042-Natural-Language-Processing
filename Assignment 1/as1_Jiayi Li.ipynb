# %% [markdown]
# # Assignment 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Jiayi Li
#
# Student ID: 1097419

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Sunday, 27 March 2022 5pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -10% per day (both week and weekend days counted)
#
# <b>Marks</b>: 9% of mark for class (with 8% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See "Using Jupyter Notebook and Python" page on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. We recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=https://www.nltk.org/book/>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each question is worth is explicitly given.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection of tweets. The task is to predict the geolocation (country) where the tweet comes from. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # Preprocessing (4 marks)

# %% [markdown]
# **Instructions**: Download the data (as1-data.json) from Canvas and put it in the same directory as this iPython notebook. Run the code below to load the json data. This produces two objects, `x` and `y`, which contains a list of  tweets and corresponding country labels (it uses the standard [2 letter country code](https://www.iban.com/country-codes)) respectively. **No implementation is needed.**

# %%
import json

x = []
y = []
data = json.load(open("as1-data.json"))
for k, v in data.items():
    x.append(k)
    y.append(v)
    
print("Number of tweets =", len(x))
print("Number of labels =", len(y))
print("\nSamples of data:")
for i in range(10):
    print("Country =", y[i], "\tTweet =", x[i])
    
assert(len(x) == 943)
assert(len(y) == 943)
# Out:
# Number of tweets = 943
# Number of labels = 943
#
# Samples of data:
# Country = us 	Tweet = @Addictd2Success thx u for following
# Country = us 	Tweet = Let's just say, if I were to ever switch teams, Khalesi would be top of the list. #girlcrush
# Country = ph 	Tweet = Taemin jonghyun!!! Your birits make me go~ http://t.co/le8z3dntlA
# Country = id 	Tweet = depart.senior 👻 rapat perdana (with Nyayu, Anita, and 8 others at Ruang Aescullap FK Unsri Madang) — https://t.co/swRALlNkrQ
# Country = ph 	Tweet = Done with internship with this pretty little lady!  (@ Metropolitan Medical Center w/ 3 others) [pic]: http://t.co/1qH61R1t5r
# Country = gb 	Tweet = Wow just Boruc's clanger! Haha Sunday League stuff that, Giroud couldn't believe his luck! #clown
# Country = my 	Tweet = I'm at Sushi Zanmai (Petaling Jaya, Selangor) w/ 5 others http://t.co/bcNobykZ
# Country = us 	Tweet = Mega Fest!!!! Its going down🙏🙌  @BishopJakes
# Country = gb 	Tweet = @EllexxxPharrell wow love the pic babe xx
# Country = us 	Tweet = You have no clue how much you hurt me

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation (based on frequency). The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); (2) lowercase all words; (3) remove any word that does not contain any English alphabets (e.g. {_hello_, _#okay_, _abc123_} would be kept, but not {_123_, _!!_}) and (4) remove stopwords (based on NLTK `stopwords`). An empty tweet (after preprocessing) and its country label should be **excluded** from the output (`x_processed` and `y_processed`).
#
# **Task**: Complete the `preprocess_data(data, labels)` function. The function takes **a list of tweets** and **a corresponding list of country labels** as input, and returns **two lists**. For the first list, each element is a bag-of-words representation of a tweet (represented using a python dictionary). For the second list, each element is a corresponding country label. Note that while we do not need to preprocess the country labels (`y`), we need to have a new output list (`y_processed`) because some tweets maybe removed after the preprocessing (due to having an empty set of bag-of-words).
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
import nltk
nltk.download('stopwords')
nltk.download('words')
nltk.download('wordnet')
nltk.download('brown')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lijiayi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /Users/lijiayi/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/lijiayi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package brown to /Users/lijiayi/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/lijiayi/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import re
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase

def preprocess_data(data, labels):
    
    ###
    # Your answer BEGINS HERE
    ###
    
    data_processed = []
    labels_processed = []
    
    for i in range(len(data)):
        tokens = tt.tokenize(data[i])                      # step 1: tokenize each tweet into individual word tokens
        tokens_lower = [token.lower() for token in tokens] # step 2: lowercase all words
        
        words_with_english_char = []                       # step 3: remove any words without English alphabets
        for token_lower in tokens_lower:
            any_english_alpha = re.findall("[a-z]", token_lower)
            if len(any_english_alpha) != 0:
                words_with_english_char.append(token_lower)
        
        words_without_stopwords = []                       # step 4: remove stopwords
        for word in words_with_english_char:
            if word not in stopwords:
                words_without_stopwords.append(word)
                
        if len(words_without_stopwords) != 0:              # Put non-empty tweet into data_processed with its label
            words_dict = dict()
            for word in words_without_stopwords:
                words_dict[word] = words_dict.get(word, 0) + 1
            
            data_processed.append(words_dict)
            labels_processed.append(labels[i])
        
    return data_processed, labels_processed

    ###
    # Your answer ENDS HERE
    ###

x_processed, y_processed = preprocess_data(x, y)

print("Number of preprocessed tweets =", len(x_processed))
print("Number of preprocessed labels =", len(y_processed))
print("\nSamples of preprocessed data:")
for i in range(10):
    print("Country =", y_processed[i], "\tTweet =", x_processed[i])
# Out:
# Number of preprocessed tweets = 943
# Number of preprocessed labels = 943
#
# Samples of preprocessed data:
# Country = us 	Tweet = {'@addictd2success': 1, 'thx': 1, 'u': 1, 'following': 1}
# Country = us 	Tweet = {"let's": 1, 'say': 1, 'ever': 1, 'switch': 1, 'teams': 1, 'khalesi': 1, 'would': 1, 'top': 1, 'list': 1, '#girlcrush': 1}
# Country = ph 	Tweet = {'taemin': 1, 'jonghyun': 1, 'birits': 1, 'make': 1, 'go': 1, 'http://t.co/le8z3dntla': 1}
# Country = id 	Tweet = {'depart.senior': 1, 'rapat': 1, 'perdana': 1, 'nyayu': 1, 'anita': 1, 'others': 1, 'ruang': 1, 'aescullap': 1, 'fk': 1, 'unsri': 1, 'madang': 1, 'https://t.co/swrallnkrq': 1}
# Country = ph 	Tweet = {'done': 1, 'internship': 1, 'pretty': 1, 'little': 1, 'lady': 1, 'metropolitan': 1, 'medical': 1, 'center': 1, 'w': 1, 'others': 1, 'pic': 1, 'http://t.co/1qh61r1t5r': 1}
# Country = gb 	Tweet = {'wow': 1, "boruc's": 1, 'clanger': 1, 'haha': 1, 'sunday': 1, 'league': 1, 'stuff': 1, 'giroud': 1, 'believe': 1, 'luck': 1, '#clown': 1}
# Country = my 	Tweet = {"i'm": 1, 'sushi': 1, 'zanmai': 1, 'petaling': 1, 'jaya': 1, 'selangor': 1, 'w': 1, 'others': 1, 'http://t.co/bcnobykz': 1}
# Country = us 	Tweet = {'mega': 1, 'fest': 1, 'going': 1, '@bishopjakes': 1}
# Country = gb 	Tweet = {'@ellexxxpharrell': 1, 'wow': 1, 'love': 1, 'pic': 1, 'babe': 1, 'xx': 1}
# Country = us 	Tweet = {'clue': 1, 'much': 1, 'hurt': 1}

# %% [markdown]
# **For your testing**:

# %%
assert(len(x_processed) == len(y_processed))
assert(len(x_processed) > 800)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(data):
    hashtags = set([])
    for d in data:
        for word, frequency in d.items():
            if word.startswith("#") and len(word) > 1:
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(x_processed)
print("Number of hashtags =", len(hashtags))
print(sorted(hashtags))
# Out:
# Number of hashtags = 425
# ['#100percentpay', '#1stsundayofoctober', '#1yearofalmostisneverenough', '#2011prdctn', '#2015eebritishfilmacademyawards', '#2k16', '#2littlebirds', '#365picture', '#5sosacousticatlanta', '#5sosfam', '#8thannualpubcrawl', '#affsuzukicup', '#aflpowertigers', '#ahimacon14', '#aim20', '#airasia', '#allcity', '#alliswell', '#allwedoiscurls', '#amazing', '#anferneehardaway', '#ariona', '#art', '#arte', '#artwork', '#ashes', '#asian', '#asiangirl', '#askcrawford', '#askherforfback', '#askolly', '#asksteven', '#at', '#australia', '#awesome', '#awesomepict', '#barcelona', '#bart', '#bayofislands', '#beautiful', '#bedimages', '#bell', '#beringmy', '#bettybooppose', '#bff', '#big', '#bigbertha', '#bigbreakfast', '#blackhat', '#blessedmorethanicanimagine', '#blessedsunday', '#blogtourambiente', '#bluemountains', '#bonekachika', '#boomtaob', '#booyaa', '#bored', '#boredom', '#bradersisterhood', '#breaktime', '#breedingground', '#bringithomemy', '#brooksengland', '#burgers', '#butitsalsokindofaphone', '#bye', '#camera', '#canadaelections', '#cbb', '#cbcolympics', '#cctv', '#cdnpoli', '#celebritycrush', '#chargers', '#chocolate', '#ciosummit', '#cleansidewalk', '#clown', '#coffeespoonart', '#colts', '#confused', '#cornell', '#country', '#craftbeer', '#creative', '#crepes', '#cumannanya', '#danny4mayor', '#data', '#date', '#datingsiteforyou', '#dearmind', '#deed', '#delightful', '#dennisrodman', '#design', '#devacurl', '#die', '#difd', '#diner', '#dinner', '#dragoncon', '#dus', '#dynamounlock', '#earrings', '#eeeeeehhh', '#election2015', '#electriccircus2014', '#endomondo', '#engine', '#english', '#europapark', '#excitables', '#fabulous', '#factorycampus', '#fall', '#familydinner', '#ff', '#fire', '#flambees', '#flashback', '#fly', '#focusateneo', '#followher', '#followme', '#foodporn', '#fotografías', '#fotorus', '#four', '#freaks', '#friday', '#fridaynight', '#fried', '#friends', '#friendshipflow', '#fries', '#frozenyoghurt', '#fun', '#future', '#galaxy', '#getfreetattooaviciipasses', '#girl', '#girlcrush', '#girls', '#givesmehope', '#goingout', '#google', '#graduated', '#grafunkthiremepls', '#grammyfans', '#grandmarnier', '#greenfood', '#grilled', '#gudnytall', '#gunner', '#gym', '#handbuiltbicycle', '#happybirthdaysandarapark', '#happyfriday', '#harimaumalaya', '#hb60', '#hens', '#hippy', '#holiday', '#hollywoodmusicawards', '#homemadegranola', '#hometomama', '#hot', '#hungergames', '#hungry', '#icu', '#ididntchoosethestudentlifeitchoseme', '#iloveyou', '#imsobored', '#imsosore', '#innoretail', '#insanity', '#insightmedia', '#insightmediasingapore', '#instaframeplus', '#instagood', '#instalook', '#isibaya', '#javaboy', '#jed', '#jewelry', '#jo', '#jordaan', '#jrsurfboards', '#justshare', '#kllive', '#ladygaga', '#latepost', '#laugh', '#laundryservice', '#lazysunday', '#learningcommunties', '#lebedeintennis', '#letmesleep', '#lfc', '#lgbt', '#life', '#lipstickfree', '#littlemonsters', '#loadsoffun', '#lol', '#longranger', '#lotsoflove', '#love', '#lovers', '#lovethisgirl', '#lovevibes', '#lte', '#magazinesandtvscreens', '#magic', '#makeupfree', '#makingemuklajawabnya', '#mamajeanneandme', '#mancrush', '#march', '#massacreconspiracy', '#mauce', '#mavic', '#me', '#meetup', '#melbourne', '#michaelkors', '#mindfulness', '#mkmedi', '#mobile', '#morning', '#mountains', '#movies', '#mtlnewtech', '#mtvhottest', '#mushroom', '#music', '#mustfollow', '#mwc14', '#mybabyemilia', '#myfriendsarebetterthanyours', '#nced', '#ncga', '#ncpol', '#nevergetsold', '#new', '#newlooks', '#newrecord', '#nextlevel', '#nfl', '#nickryrie', '#nochillzone', '#nofilter', '#notersnew2014', '#notreally', '#np', '#nye', '#of', '#offtochurch', '#ohyeah', '#oilandgas', '#olah', '#on', '#oops', '#openspace', '#oscars', '#oui', '#palacefansinthemorning', '#panther', '#panthers', '#partyhardpartyy', '#pats', '#pechanga', '#penny', '#peperoni', '#peppermoney', '#photo', '#photoby', '#photography', '#pic', '#pll', '#pmattheashes', '#pop-up', '#positivity', '#potd', '#procrastina ...

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing the **MaxMatch algorithm** discussed in class.
#
# NLTK has a list of words that you can use for matching, see starter code below (`words`). Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words (`words`) includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching (provided by the function `lemmatize(word)`). Note that the list of words (`words`) is the only source that you'll use for matching (i.e. you do not need to find  other external word lists). If you are unable to make any longer match, your code should default to matching a single letter.
#
# For example, given "#newrecord", the algorithm should produce: \["#", "new", "record"\].
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
from nltk.corpus import wordnet

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK
words = set([ word.lower() for word in words ]) #lowercase all the words for better matching

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma


def tokenize_hashtags(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    
    hashtags_dict = dict()
     
    for hashtag in hashtags: 
        tag_list = []       
        tag_list.append(hashtag[0])
        
        # reference for the following code: https://medium.com/@anshul16/maximum-matching-word-segmentation-algorithm-python-code-3444fe4bd6f9
        i = 1
        j = len(hashtag) 
        while i < j:
            max_word = ""
            temp_word = hashtag[i:j]
            if lemmatize(temp_word) in words or temp_word.isdigit():
                max_word = temp_word
                
                if max_word.isdigit():
                    for char in max_word:
                        tag_list.append(char)
                    i = i + len(max_word)
                    j = len(hashtag) 
                else:
                    i = i + len(max_word)
                    j = len(hashtag) 
                    tag_list.append(max_word)
                
            else:
                j -= 1
        
        hashtags_dict[hashtag] = tag_list
    
    return hashtags_dict
    
    ###
    # Your answer ENDS HERE
    ###

#tokenise hashtags with MaxMatch
tokenized_hashtags = tokenize_hashtags(hashtags)

#print results
for k, v in sorted(tokenized_hashtags.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'vega', 'n']
# #veganfood ['#', 'vega', 'n', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'coca', 'm']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'wear', 'e', '9', '0', 's']
# #wearesocial ['#', 'weares', 'o', 'c', 'i', 'al']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'wo', 'k']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'ama', 's']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))
assert(tokenized_hashtags["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 3 (1.0 mark)
#
# **Instructions**: Our next task is to tokenize the hashtags again, but this time using a **reversed version of the MaxMatch algorithm**, where matching begins at the end of the hashtag and progresses backwards (e.g. for <i>#helloworld</i>, we would process it right to left, starting from the last character <i>d</i>). Just like before, you should use the provided word list (`words`) for word matching.
#
# **Task**: Complete the `tokenize_hashtags_rev(hashtags)` function by the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
def tokenize_hashtags_rev(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    
    hashtags_dict = dict()
     
    for hashtag in hashtags: 
        tag_list = []       
        tag_list.append(hashtag[0])
        tag_list_rev = []
      
        i = 1
        j = len(hashtag) 
        while i < j:
            max_word = ""
            temp_word = hashtag[i:j]
            if lemmatize(temp_word) in words or temp_word.isdigit():
                max_word = temp_word
                
                if max_word.isdigit():
                    for char in list(max_word)[::-1]:
                        tag_list_rev.append(char)
                    i = 1
                    j = j - len(max_word)
                else:
                    i = 1
                    j = j - len(max_word)
                    tag_list_rev.append(max_word)
                    
            else:
                i += 1
                    
        hashtags_dict[hashtag] = tag_list + tag_list_rev[::-1]
    
    return hashtags_dict
    
    ###
    # Your answer ENDS HERE
    ###

    
#tokenise hashtags with the reversed version of MaxMatch
tokenized_hashtags_rev = tokenize_hashtags_rev(hashtags)

#print results
for k, v in sorted(tokenized_hashtags_rev.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'v', 'e', 'gan']
# #veganfood ['#', 'v', 'e', 'gan', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'c', 'o', 'cam']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'we', 'are', '9', '0', 's']
# #wearesocial ['#', 'we', 'are', 'social']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'w', 'ok']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'a', 'mas']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags_rev) == len(hashtags))
assert(tokenized_hashtags_rev["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: The two versions of MaxMatch will produce different results for some of the hashtags. For a hastag that has different results, our task here is to use a **unigram language model** (lecture 3) to score them to see which is better. Recall that in a unigram language model we compute P(<i>#</i>, <i>hello</i>, <i>world</i> = P(<i>#</i>)\*P(<i>hellow</i>)\*P(<i>world</i>).
#
# You should: (1) use the NLTK's Brown corpus (`brown_words`) for collecting word frequencies (note: the words are already tokenised so no further tokenisation is needed); (2) lowercase all words in the corpus; (3) use add-one smoothing when computing the unigram probabilities; and (4) work in the log space to prevent numerical underflow.
#
# **Task**: Build a unigram language model with add-one smoothing using the word counts from the Brown corpus. Iterate through the hashtags, and for each hashtag where MaxMatch and reversed MaxMatch produce different results, print the following: (1) the hashtag; (2) the results produced by MaxMatch and reversed MaxMatch; and (3) the log probability of each result as given by the unigram language model. Note: you **do not** need to print the hashtags where MaxMatch and reversed MaxMatch produce the same results.
#
# An example output:
# ```
# 1. #abcd
# MaxMatch = [#, a, bc, d]; LogProb = -2.3
# Reversed MaxMatch = [#, a, b, cd]; LogProb = -3.5
#
# 2. #efgh
# MaxMatch = [#, ef, g, h]; LogProb = -4.2
# Reversed MaxMatch = [#, e, fgh]; LogProb = -3.1
#
# ```
#
# Have a look at the output, and see if the sequences with better language model scores (i.e. less negative) are generally more coherent.

# %%
from nltk.corpus import brown
import math

#words from brown corpus
brown_words = brown.words()

###
# Your answer BEGINS HERE
###


# Unsmoothed corpus word frequency
word_freq = dict()
for word in brown_words:
    word_lower = word.lower()
    word_freq[word_lower] = word_freq.get(word_lower, 0) + 1
total_freq = sum(word_freq.values())

# Add-one smoothed corpus word frequency
word_freq_smooth = dict()
for word, freq in word_freq.items():
    word_freq_smooth[word] = freq + 1  
total_freq_smooth = sum(word_freq_smooth.values())

# Printer
log_prob = 0.0
log_prob_rev = 0.0
print_idx = 0

for hashtag in hashtags:
    tokenised_hashtag = tokenized_hashtags[hashtag]
    tokenised_hashtag_rev = tokenized_hashtags_rev[hashtag]
  
    if tokenised_hashtag != tokenised_hashtag_rev:
        print_idx += 1
        for token in tokenised_hashtag:
            log_prob += math.log(word_freq_smooth.get(token,1)/total_freq_smooth)
            
        for token_rev in tokenised_hashtag_rev:
            log_prob_rev += math.log(word_freq_smooth.get(token_rev,1)/total_freq_smooth)
    
        print(str(print_idx)+".", hashtag)
        print("MaxMatch =", tokenised_hashtag, ";", "LogProb =", log_prob)
        print("Reversed MaxMatch =", tokenised_hashtag_rev, ";", "LogProb =", log_prob_rev)
        
        
###
# Your answer ENDS HERE
###
# Out:
# 1. #imsosore
# MaxMatch = ['#', 'i', 'ms', 'os', 'ore'] ; LogProb = -59.69339416354492
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'sore'] ; LogProb = -48.660167171313276
# 2. #loadsoffun
# MaxMatch = ['#', 'loads', 'off', 'un'] ; LogProb = -104.22282459623897
# Reversed MaxMatch = ['#', 'loads', 'of', 'fun'] ; LogProb = -87.98077948748433
# 3. #openspace
# MaxMatch = ['#', 'opens', 'pace'] ; LogProb = -139.62631002686052
# Reversed MaxMatch = ['#', 'open', 'space'] ; LogProb = -119.0161209682172
# 4. #blogtourambiente
# MaxMatch = ['#', 'blo', 'g', 'tour', 'ambient', 'e'] ; LogProb = -213.33711179937376
# Reversed MaxMatch = ['#', 'b', 'log', 'tou', 'ram', 'bien', 'te'] ; LogProb = -208.12475537514646
# 5. #1yearofalmostisneverenough
# MaxMatch = ['#', '1', 'year', 'of', 'almost', 'is', 'never', 'enough'] ; LogProb = -274.22396803848295
# Reversed MaxMatch = ['#', '1', 'year', 'of', 'al', 'mos', 'tis', 'never', 'enough'] ; LogProb = -295.05249591911655
# 6. #startupfest
# MaxMatch = ['#', 'start', 'up', 'fest'] ; LogProb = -317.6635330643667
# Reversed MaxMatch = ['#', 'star', 'tup', 'fest'] ; LogProb = -347.8222505925565
# 7. #endomondo
# MaxMatch = ['#', 'end', 'om', 'on', 'do'] ; LogProb = -365.64790118479766
# Reversed MaxMatch = ['#', 'en', 'do', 'mon', 'do'] ; LogProb = -400.64812220783665
# 8. #photoby
# MaxMatch = ['#', 'photo', 'by'] ; LogProb = -397.30024814133776
# Reversed MaxMatch = ['#', 'pho', 'toby'] ; LogProb = -442.66901061643273
# 9. #takeabreak
# MaxMatch = ['#', 'take', 'ab', 'reak'] ; LogProb = -445.5267080325077
# Reversed MaxMatch = ['#', 'ta', 'kea', 'break'] ; LogProb = -494.208225458162
# 10. #coffeespoonart
# MaxMatch = ['#', 'coffees', 'poon', 'art'] ; LogProb = -496.21222499200434
# Reversed MaxMatch = ['#', 'coffee', 'spoon', 'art'] ; LogProb = -538.5783844161363
# 11. #longranger
# MaxMatch = ['#', 'long', 'ranger'] ; LogProb = -530.5104358841323
# Reversed MaxMatch = ['#', 'l', 'on', 'granger'] ; LogProb = -582.9569103877474
# 12. #vscocam
# MaxMatch = ['#', 'vs', 'coca', 'm'] ; LogProb = -582.0956358391034
# Reversed MaxMatch = ['#', 'vs', 'c', 'o', 'cam'] ; LogProb = -642.5892813983423
# 13. #bradersisterhood
# MaxMatch = ['#', 'brad', 'ers', 'ist', 'er', 'hood'] ; LogProb = -662.6716767534956
# Reversed MaxMatch = ['#', 'brad', 'er', 'sisterhood'] ; LogProb = -697.9239854292438
# 14. #allwedoiscurls
# MaxMatch = ['#', 'all', 'wed', 'o', 'is', 'curls'] ; LogProb = -724.3975429112472
# Reversed MaxMatch = ['#', 'all', 'w', 'edo', 'is', 'curls'] ; LogProb = -762.2525412724399
# 15. #isibaya
# MaxMatch = ['#', 'is', 'iba', 'ya'] ; LogProb = -769.59467589826
# Reversed MaxMatch = ['#', 'i', 'si', 'baya'] ; LogProb = -809.0375849217876
# 16. #wearesocial
# MaxMatch = ['#', 'weares', 'o', 'c', 'i', 'al'] ; LogProb = -833.7288378851392
# Reversed MaxMatch = ['#', 'we', 'are', 'social'] ; LogProb = -842.8509675938653
# 17. #anferneehardaway
# MaxMatch = ['#', 'an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay'] ; LogProb = -930.9534882491134
# Reversed MaxMatch = ['#', 'an', 'f', 'er', 'nee', 'hard', 'away'] ; LogProb = -917.6237916969944
# 18. #statoftheday
# MaxMatch = ['#', 'st', 'at', 'oft', 'he', 'day'] ; LogProb = -990.0149956411332
# Reversed MaxMatch = ['#', 's', 'tat', 'of', 'the', 'day'] ; LogProb = -969.6446067060322
# 19. #strictlyus
# MaxMatch = ['#', 'strictly', 'us'] ; LogProb = -1021.9933304490701
# Reversed MaxMatch = ['#', 'strict', 'l', 'yus'] ; LogProb = -1020.3543379236493
# 20. #seniorbabysenior
# MaxMatch = ['#', 'senior', 'babys', 'en', 'io', 'r'] ; LogProb = -1096.0436088364033
# Reversed MaxMatch = ['#', 'senior', 'baby', 'senior'] ; LogProb = -1065.1283582857404
# 21. #brooksengland
# MaxMatch = ['#', 'brooks', 'en', 'gland'] ; LogProb = -1144.8562200691347
# Reversed MaxMatch = ['#', 'brook', 'sen', 'gland'] ; LogProb = -1117.4673300430877
# 22. #laundryservice
# MaxMatch = ['#', 'laundrys', 'er', 'vice'] ; LogProb = -1197.1464016623124
# Reversed MaxMatch = ['#', 'laundry', 'service'] ; LogProb = -1151.9407167688687
# 23. #nevergetsold
# MaxMatch = ['#', 'never', 'gets', 'old'] ; LogProb = -1235.9260755956834
# Reversed MaxMatch = ['#', 'never', 'get', 'sold'] ; LogProb = -1190.9290746601296
# 24. #datingsiteforyou
# MaxMatch = ['#', 'datings', 'it', 'e', 'for', 'you'] ; LogProb = -1289.9204905482363
# Reversed MaxMatch = ['#', 'dating', 'site', 'for', 'you'] ; LogProb = -1237.9243390268582
# 25. #reachingyougpeople
# MaxMatch = ['#', 'reaching', 'you', 'g', 'people'] ; LogProb = -1338.4972903751323
# Reversed MaxMatch = ['#', 'reaching', 'yo', 'ug', 'people'] ; LogProb = -1297.4320827714744
# 26. #thevoiceau
# MaxMatch = ['#', 'the', 'voice', 'a', 'u'] ; LogProb = -1379.260511472356
# Reversed MaxMatch = ['#', 'the', 'v', 'o', 'i', 'c', 'ea', 'u'] ; LogProb = -1375.711154621305
# 27. #bringithomemy
# MaxMatch = ['#', 'bring', 'it', 'home', 'my'] ; LogProb = -1421.6574515121306
# Reversed MaxMatch = ['#', 'brin', 'git', 'home', 'my'] ; LogProb = -1430.645626283532
# 28. #nickryrie
# MaxMatch = ['#', 'nick', 'r', 'yr', 'ie'] ; LogProb = -1484.770607342306
# Reversed MaxMatch = ['#', 'nick', 'r', 'y', 'rie'] ; LogProb = -1491.9670226444794
# 29. #8thannualpubcrawl
# MaxMatch = ['#', '8', 'than', 'nu', 'alp', 'u', 'b', 'crawl'] ; LogProb = -1574.8755484551905
# Reversed MaxMatch = ['#', '8', 'th', 'annual', 'pub', 'crawl'] ; LogProb = -1563.6146220145913
# 30. #thankyoupatients
# MaxMatch = ['#', 'thank', 'youp', 'ati', 'en', 'ts'] ; LogProb = -1653.2269658180583
# Reversed MaxMatch = ['#', 'thank', 'you', 'patients'] ; LogProb = -1604.3229068271
# 31. #1stsundayofoctober
# MaxMatch = ['#', '1', 'st', 'sunday', 'ofo', 'c', 'tobe', 'r'] ; LogProb = -1745.9210164531273
# Reversed MaxMatch = ['#', '1', 'st', 'sunday', 'of', 'october'] ; LogProb = -1663.0166896959984
# 32. #focusateneo
# MaxMatch = ['#', 'focus', 'aten', 'e', 'o'] ; LogProb = -1805.2328494680407
# Reversed MaxMatch = ['#', 'fo', 'c', 'u', 'sate', 'neo'] ; LogProb = -1739.6153881388416
# 33. #cumannanya
# MaxMatch = ['#', 'cum', 'anna', 'n', 'ya'] ; LogProb = -1867.9152223821238
# Reversed MaxMatch = ['#', 'c', 'u', 'mannan', 'ya'] ; LogProb = -1800.5976858663855
# 34. #ariona
# MaxMatch = ['#', 'arion', 'a'] ; LogProb = -1899.8843756617234
# Reversed MaxMatch = ['#', 'ar', 'i', 'ona'] ; LogProb = -1848.0758766962929
# 35. #usydhereicome
# MaxMatch = ['#', 'us', 'y', 'd', 'here', 'i', 'come'] ; LogProb = -1964.0749652079264
# Reversed MaxMatch = ['#', 'u', 'syd', 'here', 'i', 'come'] ; LogProb = -1907.8602242880106
# 36. #innoretail
# MaxMatch = ['#', 'inn', 'ore', 'tail'] ; LogProb = -2014.5813555015254
# Reversed MaxMatch = ['#', 'in', 'no', 'retail'] ; LogProb = -1943.206747153981
# 37. #thenext5goldenyears
# MaxMatch = ['#', 'then', 'ex', 't', '5', 'golden', 'years'] ; LogProb = -2084.3626520443177
# Reversed MaxMatch = ['#', 'the', 'next', '5', 'golden', 'years'] ; LogProb = -1994.532228956763
# 38. #affsuzukicup
# MaxMatch = ['#', 'a', 'f', 'fs', 'u', 'z', 'u', 'k', 'i', 'cup'] ; LogProb = -2188.9235558520313
# Reversed MaxMatch = ['#', 'a', 'f', 'f', 'suz', 'u', 'k', 'i', 'cup'] ; LogProb = -2085.90606884781
# 39. #fotorus
# MaxMatch = ['#', 'fot', 'or', 'us'] ; LogProb = -2230.090708903859
# Reversed MaxMatch = ['#', 'fo', 'torus'] ; LogProb = -2127.9269572564062
# 40. #usydoweek
# MaxMatch = ['#', 'us', 'y', 'dow', 'e', 'e', 'k'] ; LogProb = -2308.397018660005
# Reversed MaxMatch = ['#', 'us', 'y', 'do', 'week'] ; LogProb = -2176.8152410213415
# 41. #askherforfback
# MaxMatch = ['#', 'ask', 'her', 'for', 'f', 'back'] ; LogProb = -2359.917247308088
# Reversed MaxMatch = ['#', 'ask', 'her', 'f', 'orf', 'back'] ; LogProb = -2237.493463561029
# 42. #hometomama
# MaxMatch = ['#', 'home', 'toma', 'ma'] ; LogProb = -2406.6430909590476
# Reversed MaxMatch = ['#', 'home', 'tom', 'ama'] ; LogProb = -2282.3630092216226
# 43. #shopaholic
# MaxMatch = ['#', 'shop', 'aho', 'li', 'c'] ; LogProb = -2467.715000845282
# Reversed MaxMatch = ['#', 'sho', 'paho', 'li', 'c'] ; LogProb = -2347.5938021912166
# 44. #blessedsunday
# MaxMatch = ['#', 'blesseds', 'un', 'day'] ; LogProb = -2514.570005889195
# Reversed MaxMatch = ['#', 'blessed', 'sunday'] ; LogProb = -2382.3506604569134
# 45. #flambees
# MaxMatch = ['#', 'flamb', 'e', 'es'] ; LogProb = -2566.8842850339524
# Reversed MaxMatch = ['#', 'flam', 'bees'] ; LogProb = -2421.59896014327
# 46. #toronto
# MaxMatch = ['#', 'toro', 'n', 'to'] ; LogProb = -2609.0766260207433
# Reversed MaxMatch = ['#', 'tor', 'onto'] ; LogProb = -2459.508974687693
# 47. #grandmarnier
# MaxMatch = ['#', 'grandma', 'r', 'ni', 'er'] ; LogProb = -2672.8088210593255
# Reversed MaxMatch = ['#', 'grand', 'm', 'arni', 'er'] ; LogProb = -2522.818755059853
# 48. #excitables
# MaxMatch = ['#', 'excitable', 's'] ; LogProb = -2711.694215251993
# Reversed MaxMatch = ['#', 'ex', 'c', 'i', 'tables'] ; LogProb = -2574.594612869454
# 49. #peperoni
# MaxMatch = ['#', 'pep', 'er', 'on', 'i'] ; LogProb = -2764.363256988972
# Reversed MaxMatch = ['#', 'pep', 'e', 'ro', 'ni'] ; LogProb = -2640.915854817077
# 50. #swedumtl
# MaxMatch = ['#', 's', 'wed', 'um', 't', 'l'] ; LogProb = -2835.371567218387
# Reversed MaxMatch = ['#', 's', 'we', 'dum', 't', 'l'] ; LogProb = -2706.748768893457
# 51. #mtlnewtech
# MaxMatch = ['#', 'm', 't', 'l', 'newt', 'e', 'c', 'h'] ; LogProb = -2923.5112626073865
# Reversed MaxMatch = ['#', 'm', 't', 'l', 'new', 'tech'] ; LogProb = -2771.1701761013487
# 52. #skullsearcher
# MaxMatch = ['#', 'skulls', 'ear', 'che', 'r'] ; LogProb = -2984.689558124693
# Reversed MaxMatch = ['#', 'skull', 'searcher'] ; LogProb = -2811.804770148825
# 53. #nced
# MaxMatch = ['#', 'n', 'ce', 'd'] ; LogProb = -3033.1220220573005
# Reversed MaxMatch = ['#', 'n', 'c', 'ed'] ; LogProb = -2856.725981339808
# 54. #olah
# MaxMatch = ['#', 'o', 'la', 'h'] ; LogProb = -3078.7056906588577
# Reversed MaxMatch = ['#', 'o', 'l', 'ah'] ; LogProb = -2903.4892881252804
# 55. #ciosummit
# MaxMatch = ['#', 'c', 'ios', 'um', 'mi', 't'] ; LogProb = -3150.591005331073
# Reversed MaxMatch = ['#', 'c', 'io', 'summit'] ; LogProb = -2951.4550217539872
# 56. #goingout
# MaxMatch = ['#', 'going', 'out'] ; LogProb = -3178.971689403605
# Reversed MaxMatch = ['#', 'go', 'in', 'gout'] ; LogProb = -2989.9750693363962
# 57. #vegan
# MaxMatch = ['#', 'vega', 'n'] ; LogProb = -3217.3290161660716
# Reversed MaxMatch = ['#', 'v', 'e', 'gan'] ; LogProb = -3038.9571439709784
# 58. #lebedeintennis
# MaxMatch = ['#', 'l', 'e', 'bed', 'e', 'in', 'tennis'] ; LogProb = -3287.5245345227536
# Reversed MaxMatch = ['#', 'l', 'e', 'be', 'de', 'in', 'tennis'] ; LogProb = -3104.1454704553416
# 59. #rainorshine
# MaxMatch = ['#', 'rain', 'ors', 'hin', 'e'] ; LogProb = -3349.583096593335
# Reversed MaxMatch = ['#', 'r', 'ai', 'nor', 'shine'] ; LogProb = -3162.7537015145203
# 60. #southampton
# MaxMatch = ['#', 'south', 'am', 'p', 'ton'] ; LogProb = -3401.677980249031
# Reversed MaxMatch = ['#', 's', 'out', 'ham', 'p', 'ton'] ; LogProb = -3226.0326493018047
# 61. #cornell
# MaxMatch = ['#', 'cornel', 'l'] ; LogProb = -3440.865655313571
# Reversed MaxMatch = ['#', 'cor', 'nell'] ; LogProb = -3267.360390529841
# 62. #pechanga
# MaxMatch = ['#', 'pech', 'an', 'ga'] ; LogProb = -3487.9732511101247
# Reversed MaxMatch = ['#', 'p', 'e', 'changa'] ; LogProb = -3315.330864252745
# 63. #arte
# MaxMatch = ['#', 'art', 'e'] ; LogProb = -3520.938233200052
# Reversed MaxMatch = ['#', 'ar', 'te'] ; LogProb = -3357.3517526613414
# 64. #txlege
# MaxMatch = ['#', 't', 'x', 'leg', 'e'] ; LogProb = -3576.0526401548395
# Reversed MaxMatch = ['#', 't', 'x', 'l', 'e', 'ge'] ; LogProb = -3426.6188342301757
# 65. #potd
# MaxMatch = ['#', 'pot', 'd'] ; LogProb = -3610.7744071007246
# Reversed MaxMatch = ['#', 'po', 'td'] ; LogProb = -3467.946575458212
# 66. #grammyfans
# MaxMatch = ['#', 'gram', 'my', 'fans'] ; LogProb = -3654.128691433312
# Reversed MaxMatch = ['#', 'g', 'rammy', 'fans'] ; LogProb = -3518.050170872259
# 67. #pmattheashes
# MaxMatch = ['#', 'p', 'matt', 'he', 'ashes'] ; LogProb = -3707.3233037996592
# Reversed MaxMatch = ['#', 'p', 'mat', 'the', 'ashes'] ; LogProb = -3568.8476594054387
# 68. #uptonogood
# MaxMatch = ['#', 'up', 'ton', 'og', 'o', 'od'] ; LogProb = -3777.885325352574
# Reversed MaxMatch = ['#', 'up', 'to', 'no', 'good'] ; LogProb = -3606.80377899628
# 69. #ididntchoosethestudentlifeitchoseme
# MaxMatch = ['#', 'id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me'] ; LogProb = -3921.537388079939
# Reversed MaxMatch = ['#', 'i', 'didnt', 'choose', 'the', 'student', 'life', 'it', 'cho', 'seme'] ; LogProb = -3702.7015231474315
# 70. #learningcommunties
# MaxMatch = ['#', 'learning', 'c', 'om', 'munt', 'ies'] ; LogProb = -3996.664269988225
# Reversed MaxMatch = ['#', 'learning', 'c', 'om', 'm', 'unties'] ; LogProb = -3774.9951917116614
# 71. #difd
# MaxMatch = ['#', 'di', 'f', 'd'] ; LogProb = -4042.013883438389
# Reversed MaxMatch = ['#', 'd', 'if', 'd'] ; LogProb = -3815.463633667119
# 72. #cleansidewalk
# MaxMatch = ['#', 'cleans', 'ide', 'walk'] ; LogProb = -4092.7334669524494
# Reversed MaxMatch = ['#', 'clean', 'sidewalk'] ; LogProb = -3850.1449843803075
# 73. #google
# MaxMatch = ['#', 'goo', 'g', 'l', 'e'] ; LogProb = -4153.3882822119585
# Reversed MaxMatch = ['#', 'go', 'ogle'] ; LogProb = -3885.724926248271
# 74. #cbcolympics
# MaxMatch = ['#', 'c', 'b', 'coly', 'm', 'pics'] ; LogProb = -4225.129385546248
# Reversed MaxMatch = ['#', 'c', 'b', 'col', 'ym', 'pics'] ; LogProb = -3960.2992429266183
# 75. #bettybooppose
# MaxMatch = ['#', 'betty', 'boo', 'p', 'pose'] ; LogProb = -4286.256045947254
# Reversed MaxMatch = ['#', 'betty', 'bo', 'oppose'] ; LogProb = -4011.47506387416
# 76. #jordaan
# MaxMatch = ['#', 'jo', 'r', 'da', 'an'] ; LogProb = -4339.681691209808
# Reversed MaxMatch = ['#', 'j', 'or', 'da', 'an'] ; LogProb = -4060.2197656992525
# 77. #burgers
# MaxMatch = ['#', 'burg', 'ers'] ; LogProb = -4381.702579618403
# Reversed MaxMatch = ['#', 'bur', 'gers'] ; LogProb = -4102.240654107849
# 78. #askolly
# MaxMatch = ['#', 'ask', 'o', 'l', 'ly'] ; LogProb = -4440.748531018307
# Reversed MaxMatch = ['#', 'as', 'kol', 'ly'] ; LogProb = -4149.379196999466
# 79. #harimaumalaya
# MaxMatch = ['#', 'ha', 'rima', 'um', 'ala', 'ya'] ; LogProb = -4520.472819721963
# Reversed MaxMatch = ['#', 'h', 'ar', 'i', 'mau', 'mala', 'ya'] ; LogProb = -4234.090784495187
# 80. #foodporn
# MaxMatch = ['#', 'food', 'po', 'r', 'n'] ; LogProb = -4577.490150989707
# Reversed MaxMatch = ['#', 'food', 'p', 'or', 'n'] ; LogProb = -4282.776514084177
# 81. #ladygaga
# MaxMatch = ['#', 'lady', 'gag', 'a'] ; LogProb = -4617.462380005066
# Reversed MaxMatch = ['#', 'lady', 'g', 'aga'] ; LogProb = -4331.576702796909
# 82. #blackhat
# MaxMatch = ['#', 'black', 'hat'] ; LogProb = -4650.122097151983
# Reversed MaxMatch = ['#', 'b', 'lac', 'khat'] ; LogProb = -4382.941114914257
# 83. #jrsurfboards
# MaxMatch = ['#', 'j', 'rs', 'urf', 'boards'] ; LogProb = -4714.339800006346
# Reversed MaxMatch = ['#', 'j', 'r', 'surfboards'] ; LogProb = -4433.359494330533
# 84. #yiamas
# MaxMatch = ['#', 'y', 'i', 'ama', 's'] ; LogProb = -4770.204552773402
# Reversed MaxMatch = ['#', 'y', 'i', 'a', 'mas'] ; LogProb = -4483.00115336508
# 85. #letmesleep
# MaxMatch = ['#', 'let', 'mes', 'leep'] ; LogProb = -4820.279160650574
# Reversed MaxMatch = ['#', 'let', 'me', 'sleep'] ; LogProb = -4521.8111433022605
# 86. #socal
# MaxMatch = ['#', 'soc', 'al'] ; LogProb = -4859.041952521148
# Reversed MaxMatch = ['#', 'so', 'cal'] ; LogProb = -4555.545006685691
# 87. #uniexamonasaturday
# MaxMatch = ['#', 'unie', 'x', 'am', 'ona', 'saturday'] ; LogProb = -4930.619362237252
# Reversed MaxMatch = ['#', 'u', 'ni', 'ex', 'a', 'mona', 'saturday'] ; LogProb = -4635.5848338532915
# 88. #palacefansinthemorning
# MaxMatch = ['#', 'palace', 'fans', 'in', 'them', 'or', 'ning'] ; LogProb = -4996.111335790971
# Reversed MaxMatch = ['#', 'palace', 'fan', 'sin', 'the', 'morning'] ; LogProb = -4692.517189282941
# 89. #ahimacon14
# MaxMatch = ['#', 'ah', 'ima', 'con', '1', '4'] ; LogProb = -5063.336361773581
# Reversed MaxMatch = ['#', 'a', 'hi', 'macon', '1', '4'] ; LogProb = -4751.350067832675
# 90. #bedimages
# MaxMatch = ['#', 'bedim', 'ages'] ; LogProb = -5101.406006463595
# Reversed MaxMatch = ['#', 'bed', 'images'] ; LogProb = -4784.881339817625
# 91. #ritenow
# MaxMatch = ['#', 'rite', 'now'] ; LogProb = -5134.048078350243
# Reversed MaxMatch = ['#', 'rit', 'enow'] ; LogProb = -4826.90222822622
# 92. #beringmy
# MaxMatch = ['#', 'beri', 'n', 'g', 'my'] ; LogProb = -5190.401488221665
# Reversed MaxMatch = ['#', 'be', 'ring', 'my'] ; LogProb = -4863.113639426486
# 93. #magazinesandtvscreens
# MaxMatch = ['#', 'magazines', 'and', 't', 'vs', 'creen', 's'] ; LogProb = -5265.820486438142
# Reversed MaxMatch = ['#', 'magazine', 'sand', 't', 'v', 'screens'] ; LogProb = -4930.012432349914
# 94. #samsung
# MaxMatch = ['#', 'sams', 'un', 'g'] ; LogProb = -5316.376066975931
# Reversed MaxMatch = ['#', 'sam', 'sung'] ; LogProb = -4964.706855144669
# 95. #alliswell
# MaxMatch = ['#', 'all', 'is', 'well'] ; LogProb = -5348.375433794882
# Reversed MaxMatch = ['#', 'al', 'li', 'swell'] ; LogProb = -5015.397168276429
# 96. #surfshop
# MaxMatch = ['#', 'surfs', 'hop'] ; LogProb = -5389.297709914809
# Reversed MaxMatch = ['#', 'surf', 'shop'] ; LogProb = -5052.566026421105
# 97. #thewalkingdead
# MaxMatch = ['#', 'thew', 'alk', 'ing', 'dead'] ; LogProb = -5454.167737955211
# Reversed MaxMatch = ['#', 'the', 'walking', 'dead'] ; LogProb = -5088.2659080324
# 98. #instalook
# MaxMatch = ['#', 'ins', 'tal', 'o', 'ok'] ; LogProb = -5519.114955634304
# Reversed MaxMatch = ['#', 'ins', 'ta', 'look'] ; LogProb = -5138.302294696752
# 99. #veganfood
# MaxMatch = ['#', 'vega', 'n', 'food'] ; LogProb = -5566.482032925872
# Reversed MaxMatch = ['#', 'v', 'e', 'gan', 'food'] ; LogProb = -5196.294119860435
# 100. #melbourne
# MaxMatch = ['#', 'mel', 'bourn', 'e'] ; LogProb = -5615.905940312733
# Reversed MaxMatch = ['#', 'm', 'elb', 'our', 'ne'] ; LogProb = -5254.416514426754
# 101. #startuphub
# MaxMatch = ['#', 'start', 'up', 'hub'] ; LogProb = -5656.860598688829
# Reversed MaxMatch = ['#', 'star', 'tup', 'hub'] ; LogProb = -5304.701362450405
# 102. #getfreetattooaviciipasses
# MaxMatch = ['#', 'get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'passes'] ; LogProb = -5742.900881780658
# Reversed MaxMatch = ['#', 'get', 'free', 'tattoo', 'a', 'vic', 'i', 'i', 'passes'] ; LogProb = -5386.490574523933
# 103. #makeupfree
# MaxMatch = ['#', 'make', 'up', 'free'] ; LogProb = -5779.144848177791
# Reversed MaxMatch = ['#', 'ma', 'keup', 'free'] ; LogProb = -5433.962011830824
# 104. #blessedmorethanicanimagine
# MaxMatch = ['#', 'blessed', 'more', 'than', 'i', 'can', 'imagine'] ; LogProb = -5839.2033189456315
# Reversed MaxMatch = ['#', 'blessed', 'more', 'th', 'ani', 'can', 'imagine'] ; LogProb = -5508.9620600936105
# 105. #singapore
# MaxMatch = ['#', 'sing', 'a', 'pore'] ; LogProb = -5880.525474677938
# Reversed MaxMatch = ['#', 's', 'inga', 'pore'] ; LogProb = -5560.755804800474
# 106. #wok
# MaxMatch = ['#', 'wo', 'k'] ; LogProb = -5920.148467813735
# Reversed MaxMatch = ['#', 'w', 'ok'] ; LogProb = -5599.193174270613
# 107. #skeemsaam
# MaxMatch = ['#', 'skee', 'ms', 'aam'] ; LogProb = -5975.077706736527
# Reversed MaxMatch = ['#', 's', 'k', 'e', 'ems', 'aam'] ; LogProb = -5673.987989532372
# 108. #imsobored
# MaxMatch = ['#', 'i', 'ms', 'o', 'bored'] ; LogProb = -6029.460361013525
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'bored'] ; LogProb = -5722.33800177538
# 109. #instagood
# MaxMatch = ['#', 'ins', 'tag', 'o', 'od'] ; LogProb = -6094.407578692618
# Reversed MaxMatch = ['#', 'ins', 'ta', 'good'] ; LogProb = -5771.67252931857
# 110. #happybirthdaysandarapark
# MaxMatch = ['#', 'happy', 'birthdays', 'anda', 'rap', 'ark'] ; LogProb = -6172.755623371006
# Reversed MaxMatch = ['#', 'happy', 'birthday', 'sand', 'ara', 'park'] ; LogProb = -5840.253574584874
# 111. #siberuang
# MaxMatch = ['#', 'sib', 'er', 'uang'] ; LogProb = -6228.783474582466
# Reversed MaxMatch = ['#', 'si', 'ber', 'uang'] ; LogProb = -5895.5882786157745
# 112. #asksteven
# MaxMatch = ['#', 'asks', 'te', 'v', 'en'] ; LogProb = -6290.46220356577
# Reversed MaxMatch = ['#', 'ask', 'steven'] ; LogProb = -5932.7493546200085
# 113. #booyaa
# MaxMatch = ['#', 'boo', 'ya', 'a'] ; LogProb = -6334.1357345552415
# Reversed MaxMatch = ['#', 'boo', 'y', 'aa'] ; LogProb = -5985.599152001122
# 114. #scifigeek
# MaxMatch = ['#', 's', 'c', 'if', 'i', 'geek'] ; LogProb = -6393.992577739662
# Reversed MaxMatch = ['#', 's', 'c', 'i', 'fi', 'geek'] ; LogProb = -6053.151753176097
# 115. #insightmediasingapore
# MaxMatch = ['#', 'insight', 'media', 'sing', 'a', 'pore'] ; LogProb = -6457.554107532155
# Reversed MaxMatch = ['#', 'insight', 'me', 'di', 'as', 'inga', 'pore'] ; LogProb = -6127.866620557818
# 116. #butitsalsokindofaphone
# MaxMatch = ['#', 'but', 'its', 'also', 'kind', 'of', 'a', 'phone'] ; LogProb = -6516.410199086885
# Reversed MaxMatch = ['#', 'bu', 'tits', 'also', 'kin', 'do', 'fa', 'phone'] ; LogProb = -6219.524174452312
# 117. #pop-up
# MaxMatch = ['#', 'pop'] ; LogProb = -6542.344683150935
# Reversed MaxMatch = ['#', 'up'] ; LogProb = -6239.993238989384
# 118. #meetup
# MaxMatch = ['#', 'meet', 'up'] ; LogProb = -6571.810075196777
# Reversed MaxMatch = ['#', 'me', 'e', 'tup'] ; LogProb = -6285.232554936174
# 119. #cdnpoli
# MaxMatch = ['#', 'c', 'd', 'n', 'pol', 'i'] ; LogProb = -6634.902783308828
# Reversed MaxMatch = ['#', 'c', 'd', 'n', 'po', 'li'] ; LogProb = -6356.181776249219
# 120. #fotografías
# MaxMatch = ['#', 'fot', 'og', 'ra', 'f'] ; LogProb = -6700.633532229949
# Reversed MaxMatch = ['#', 'as'] ; LogProb = -6375.3063935351065
# 121. #thankyoulord
# MaxMatch = ['#', 'thank', 'youl', 'or', 'd'] ; LogProb = -6754.781097615316
# Reversed MaxMatch = ['#', 'thank', 'you', 'lord'] ; LogProb = -6415.082301477988
# 122. #mamajeanneandme
# MaxMatch = ['#', 'mam', 'a', 'jeanne', 'and', 'me'] ; LogProb = -6811.426172195038
# Reversed MaxMatch = ['#', 'm', 'ama', 'jeanne', 'and', 'me'] ; LogProb = -6478.252750662091
# 123. #weare90s
# MaxMatch = ['#', 'wear', 'e', '9', '0', 's'] ; LogProb = -6877.756734848819
# Reversed MaxMatch = ['#', 'we', 'are', '9', '0', 's'] ; LogProb = -6535.608735156776
# 124. #oilandgas
# MaxMatch = ['#', 'oil', 'and', 'gas'] ; LogProb = -6914.345063772318
# Reversed MaxMatch = ['#', 'o', 'i', 'land', 'gas'] ; LogProb = -6583.803810007739
# 125. #myfriendsarebetterthanyours
# MaxMatch = ['#', 'my', 'friends', 'are', 'better', 'than', 'yours'] ; LogProb = -6974.950296768418
# Reversed MaxMatch = ['#', 'my', 'friend', 'sare', 'better', 'than', 'yours'] ; LogProb = -6652.993176214814

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict the country of origin of a given tweet. The task here is to create training, development and test partitions from the preprocessed data (`x_processed`) and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 70%/15%/15% ratio. Remember to preserve the ratio of the classes for all your partitions. That is, say we have only 2 classes and 70% of instances are labelled class A and 30% of instances are labelled class B, then the instances in training, development and test partitions should also preserve this 7:3 ratio. You may use sklearn's builtin functions for doing data partitioning.
#
# Next, turn the bag-of-words dictionary of each tweet into a feature vector. You may also use sklearn's builtin functions for doing this (but if you don't want to use sklearn that's fine).
#
# You should produce 6 objects: `x_train`, `x_dev`, `x_test` which contain the input feature vectors, and `y_train`, `y_dev` and `y_test` which contain the labels.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split

x_train, x_dev, x_test = None, None, None
y_train, y_dev, y_test = None, None, None

###
# Your answer BEGINS HERE
###

# Split data
x_train, x_test, y_train, y_test = train_test_split(x_processed, y_processed, train_size=0.7, test_size=0.3, random_state=9999, stratify=y_processed)
x_dev, x_test, y_dev, y_test = train_test_split(x_test, y_test, train_size=0.5, test_size=0.5, random_state=9999, stratify=y_test)

# Vectorize data
vectorizer = DictVectorizer(sparse=False)
x_train = vectorizer.fit_transform(x_train)
x_dev = vectorizer.transform(x_dev)
x_test = vectorizer.transform(x_test)

print(len(x_train))
print(len(x_dev))
print(len(x_test))

###
# Your answer ENDS HERE
###
# Out:
# 660
# 141
# 142

# %% [markdown]
# ### Question 6 (1.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation hyper-parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the **accuracy** with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance (accuracy) for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

###
# Your answer BEGINS HERE
###

# NBclf = MultinomialNB(alpha=1)
# NBclf.fit(x_train, y_train)
# print("Naive Bayes accuracy", NBclf.score(x_dev, y_dev))


A = [0.01, 0.05, 0.075, 0.1, 0.25, 0.4, 0.55, 0.7, 0.85, 1, 1.15, 1.3, 1.45, 1.6, 1.75, 2.05, 2.2, 2.35, 2.5, 2.65, 2.8, 2.95, 3.1, 3.5, 3.65, 3.8, 3.9, 4, 4.5, 5, 5.5, 6]
for a in A:
    NBclf = MultinomialNB(alpha=a)
    NBclf.fit(x_train, y_train)
    print("Naive Bayes accuracy", NBclf.score(x_dev, y_dev), "alpha =", a)

C = [0.1, 0.25, 0.4, 0.55, 0.7, 0.85, 1, 1.15, 1.3, 1.45, 1.6, 1.75, 2.05, 2.2, 2.35, 2.5, 2.65, 2.8, 2.95, 3.1, 3.5, 3.65, 3.8, 3.9, 4, 4.5, 5, 5.5, 6]
for c in C:
    LRclf = LogisticRegression(random_state=999, C=c)
    LRclf.fit(x_train, y_train)
    print("Logistic Regressions accuracy", LRclf.score(x_dev, y_dev), "regularization strength =", c)
    
###
# Your answer ENDS HERE
###
# Out:
# Naive Bayes accuracy 0.2765957446808511 alpha = 0.01
# Naive Bayes accuracy 0.2695035460992908 alpha = 0.05
# Naive Bayes accuracy 0.2765957446808511 alpha = 0.075
# Naive Bayes accuracy 0.2765957446808511 alpha = 0.1
# Naive Bayes accuracy 0.2765957446808511 alpha = 0.25
# Naive Bayes accuracy 0.2765957446808511 alpha = 0.4
# Naive Bayes accuracy 0.2695035460992908 alpha = 0.55
# Naive Bayes accuracy 0.2695035460992908 alpha = 0.7
# Naive Bayes accuracy 0.2695035460992908 alpha = 0.85
# Naive Bayes accuracy 0.2765957446808511 alpha = 1
# Naive Bayes accuracy 0.2765957446808511 alpha = 1.15
# Naive Bayes accuracy 0.2765957446808511 alpha = 1.3
# Naive Bayes accuracy 0.2765957446808511 alpha = 1.45
# Naive Bayes accuracy 0.2765957446808511 alpha = 1.6
# Naive Bayes accuracy 0.2765957446808511 alpha = 1.75
# Naive Bayes accuracy 0.2695035460992908 alpha = 2.05
# Naive Bayes accuracy 0.2695035460992908 alpha = 2.2
# Naive Bayes accuracy 0.2695035460992908 alpha = 2.35
# Naive Bayes accuracy 0.2695035460992908 alpha = 2.5
# Naive Bayes accuracy 0.2695035460992908 alpha = 2.65
# Naive Bayes accuracy 0.2695035460992908 alpha = 2.8
# Naive Bayes accuracy 0.2624113475177305 alpha = 2.95
# Naive Bayes accuracy 0.2624113475177305 alpha = 3.1
# Naive Bayes accuracy 0.2624113475177305 alpha = 3.5
# Naive Bayes accuracy 0.2624113475177305 alpha = 3.65
# Naive Bayes accuracy 0.2624113475177305 alpha = 3.8
# Naive Bayes accuracy 0.2624113475177305 alpha = 3.9
# Naive Bayes accuracy 0.2624113475177305 alpha = 4
# Naive Bayes accuracy 0.2624113475177305 alpha = 4.5
# Naive Bayes accuracy 0.2624113475177305 alpha = 5
# Naive Bayes accuracy 0.2624113475177305 alpha = 5.5
# Naive Bayes accuracy 0.2624113475177305 alpha = 6
# Logistic Regressions accuracy 0.2978723404255319 regularization strength = 0.1
# Logistic Regressions accuracy 0.3191489361702128 regularization strength = 0.25
# Logistic Regressions accuracy 0.3191489361702128 regularization strength = 0.4
# Logistic Regressions accuracy 0.3191489361702128 regularization strength = 0.55
# Logistic Regressions accuracy 0.3120567375886525 regularization strength = 0.7
# Logistic Regressions accuracy 0.3191489361702128 regularization strength = 0.85
# Logistic Regressions accuracy 0.3191489361702128 regularization strength = 1
# Logistic Regressions accuracy 0.3191489361702128 regularization strength = 1.15
# Logistic Regressions accuracy 0.3262411347517731 regularization strength = 1.3
# Logistic Regressions accuracy 0.3262411347517731 regularization strength = 1.45
# Logistic Regressions accuracy 0.3262411347517731 regularization strength = 1.6
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 1.75
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 2.05
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 2.2
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 2.35
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 2.5
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 2.65
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 2.8
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 2.95
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 3.1
# Logistic Regressions accuracy 0.3404255319148936 regularization strength = 3.5
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 3.65
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 3.8
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 3.9
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 4
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 4.5
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 5
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 5.5
# Logistic Regressions accuracy 0.3333333333333333 regularization strength = 6

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both **accuracy** and **macro-averaged F-score** for each classifier. Be sure to label your output. You may use sklearn's inbuilt functions.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using their optimal hyper-parameter settings based on their development performance.

# %%
###
# Your answer BEGINS HERE
###

from sklearn.metrics import accuracy_score, f1_score

NBclfbest = MultinomialNB(alpha=1)
NBclfbest.fit(x_train, y_train)

y_predict_NB = NBclfbest.predict(x_test)

print("Naive Bayes accuracy", accuracy_score(y_test, y_predict_NB))
print("Naive Bayes F-score", f1_score(y_test, y_predict_NB, average='macro'))

LRclfbest = LogisticRegression(random_state=999, C=2.05)
LRclfbest.fit(x_train, y_train)

y_predict_LR = LRclfbest.predict(x_test)

print("Logistic Regressions accuracy", accuracy_score(y_test, y_predict_LR))
print("Logistic Regressions F-score", f1_score(y_test, y_predict_LR, average='macro'))

###
# Your answer ENDS HERE
###
# Out:
# Naive Bayes accuracy 0.33098591549295775
# Naive Bayes F-score 0.3230071264477158
# Logistic Regressions accuracy 0.3028169014084507
# Logistic Regressions F-score 0.2679507079120082

# %% [markdown]
# ### Question 8 (1.0 mark)
#
# **Instructions**: Print the most important features and their weights for each class for the two classifiers.
#
#
# **Task**: For each of the classifiers (Logistic Regression and Naive Bayes) you've built in the previous question, print out the top-20 features (words) with the highest weight for each class (countries).
#
# An example output:
# ```
# Classifier = Logistic Regression
#
# Country = au
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Country = ca
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Classifier = Naive Bayes
#
# Country = au
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
#
# Country = ca
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
# ```
#
# Have a look at the output, and see if you notice any trend/pattern in the words for each country.

# %%
###
# Your answer BEGINS HERE
###

print("Classifier = Logistic Regression")
coef = LRclf.coef_
print(coef)


print("Classifier = Naive Bayes")
        
###
# Your answer ENDS HERE
###
# Out:
# Classifier = Logistic Regression
# [[-0.02761135 -0.01797135 -0.10769981 ... -0.01715442 -0.06421294
#   -0.01210617]
#  [-0.02836183 -0.02148898 -0.08637642 ...  0.473731    0.68519622
#   -0.02098661]
#  [ 0.37382067 -0.01286685 -0.05566877 ... -0.01143091 -0.03598029
#   -0.08731369]
#  ...
#  [-0.03355636 -0.02463994 -0.1018209  ... -0.05215718 -0.05971114
#   -0.00863253]
#  [-0.0309109  -0.04301881 -0.10844011 ... -0.12542831 -0.08210849
#   -0.06600108]
#  [-0.07042037  0.2748424  -0.10288683 ... -0.08299396 -0.0975735
#    0.34441415]]
# Classifier = Naive Bayes
